# %%
import math
import matplotlib.pyplot as pl

g,m,t,v= 9.8,68.1,10,40

rX1, rX2=[],[]
Et,Et1=[],[]
I1,I2=[],[]

vV=14.780204

def f(c):
    
    y= (g*m/c)*(1-math.e**((-c/m)*t))-v
    
    return y

def encontrarRaiz(Xl,Xu,ban):
    
    Xr=0.0
    
    c1,c2=0,0 
    
    while True :
        
        if(ban==True):
            Xr=((Xl+Xu)/2)
            rX1.append(Xr)
            Et.append(abs((vV-Xr)/vV)*100)
            I1.append(c1+1)
            c1+=1
            
        else:
            Xr=Xu-(f(Xu)*(Xl-Xu)/(f(Xl)-f(Xu)))
            rX2.append(Xr)
            Et1.append(abs((vV-Xr)/vV)*100)
            I2.append(c2+1)
            c2+=1
        
        if(f(Xl)*f(Xr))<0:
            Xu=Xr
        
        else:
            if(f(Xl)*f(Xr))>0:
                Xl=Xr
            else:
                break
     
    return Xr

def graf():
     
    print( encontrarRaiz(12,16,True))
    print( encontrarRaiz(12,16,False))
    
    pl.ylabel('Error Relativo Porcentual Verdadero')
    pl.xlabel('Iteraciones')
   
    pl.plot(I1,Et,color="green",label='Et metodo de biseccion',linewidth=2.5, linestyle="-")
    pl.plot(I2,Et1,color="pink",label='Et metodo de falsa posicion',linewidth=2.5, linestyle="-")
    pl.axis([-1,15,-1,6])
    pl.grid(True)
    pl.legend()
    pl.show() 
    
graf()
# Out:
# 14.780203831661057
# 14.780203831661057

# %%
import math
import matplotlib.pyplot as pl
from tabulate import tabulate
#5.1

Et=[]
Ea=[]

fo=[]
xo=[]

Xro=[]

tabla=[]

vV=-1.4051 
vVo=6.4051
Xr_my=0

def f(x):
    
    y=-0.5*x**2 + 2.5*x + 4.5
    
    return y

def met_biseccion(Xl,Xu):
    
    Xr=0.0
    
    vAct=0
    vAnt=0
    
    c1=0
    i=0
    
    global tabla
    
    while c1<3:
    
        Xr=((Xl+Xu)/2)
        Ett=abs((vVo-Xr)/vVo)*100
        Et.append(Ett)
        Xro.append(Xr)
        
        if(c1>0):
            Ea.append(abs((((Xro[c1]-Xro[c1-1])/Xro[c1])*100)))
            tabla.append([Xl,Xu,Xr,Ett,Ea[c1-1]])
        else:
            tabla.append([Xl,Xu,Xr,Ett,""])
            
            
            
        if(f(Xl)*f(Xr))<0:
            Xu=Xr
        
        else:
            if(f(Xl)*f(Xr))>0:
                Xl=Xr
            else:
                break
                
        c1+=1
    
    return Xr

def encontrarRaiz_form_cua():
    
    a=-0.5
    b=2.5
    c=4.5
    
    y=(-2.5+math.sqrt((b**2)-4*a*c))/(2*a)
    yo=(-2.5-math.sqrt((b**2) - 4*a*c))/(2*a)
    
    print(chr(27)+"[1;47m"+" Raiz 1 : %f    Raiz 2 : %f"%(y,yo))
   

def graf():
    
    print("")
    print("Raiz mas grande por metodo de biseccion:",vVo)
    
    x=-3
    
    while x<20:
        fo.append(f(x))
        xo.append(x)
        x+=1
    
    pl.ylabel('f(X)')
    pl.xlabel('X')
   
    pl.plot(xo,fo,color="green",linewidth=2.5, linestyle="-")
    pl.plot(6.405125,0,'ro',color="pink",label="Raiz mas grande",linewidth=3)
   
    pl.axis([-5,15,-4,8])
    pl.grid(True)
    pl.legend()
    pl.show()


encontrarRaiz_form_cua()
met_biseccion(5,10)

print(chr(27)+"[0m")
headers=["Xl","Xu","Xr","Et","Ea","Raices"]

print(tabulate(tabla,headers))
graf()
# Out:
#  Raiz 1 : -1.405125    Raiz 2 : 6.405125
#
#   Xl    Xu     Xr        Et  Ea
# ----  ----  -----  --------  -----------------
# 5     10    7.5    17.0942
# 5      7.5  6.25    2.42151  20.0
# 6.25   7.5  6.875   7.33634  9.090909090909092
#
# Raiz mas grande por metodo de biseccion: 6.4051

# %%
import math
import matplotlib.pyplot as pl
from tabulate import tabulate
#5.2

Ea=[]

fo=[]
xo=[]

Xro=[]

tabla=[]

Es=0.1
vVer=0.44

def f(x):
    
    y=5*x**3 - 5*x**2 + 6*x - 2
    
    return y

def met_biseccion(Xl,Xu):
    
    Xr=0.0
    
    Eapx=1
    
    c1=0
    
    while Eapx>Es:
    
        Xr=((Xl+Xu)/2)
        Xro.append(Xr)
        
        if(c1>0):
            Eapx=(abs((((Xro[c1]-Xro[c1-1])/Xro[c1])*100)))
            Ea.append(Eapx)
            tabla.append([Xl,Xu,Xr,Ea[c1-1]])
            
        else:
            tabla.append([Xl,Xu,Xr,""])
            
        if(f(Xl)*f(Xr))<0:
            Xu=Xr
        
        else:
            if(f(Xl)*f(Xr))>0:
                Xl=Xr
            else:
                break
                
        c1+=1
    
    print(tabulate(tabla,headers=["Xl","Xu","Xr","Ea"]))
    return Xr
   

def graf():
    
    print("Valor Real: ",0.44)
    
    
    x=-50
    
    while x<500:
        fo.append(f(x))
        xo.append(x)
        x+=1
    
    pl.ylabel('f(X)')
    pl.xlabel('X')
   
    pl.plot(xo,fo,color="green",linewidth=2.5, linestyle="-")
   
    pl.axis([-10,15,-4,8])
    pl.grid(True)
    pl.show()

graf()
met_biseccion(0,1)
# Out:
# Valor Real:  0.44
#       Xl        Xu        Xr  Ea
# --------  --------  --------  -------------------
# 0         1         0.5
# 0         0.5       0.25      100.0
# 0.25      0.5       0.375     33.33333333333333
# 0.375     0.5       0.4375    14.285714285714285
# 0.375     0.4375    0.40625   7.6923076923076925
# 0.40625   0.4375    0.421875  3.7037037037037033
# 0.40625   0.421875  0.414062  1.8867924528301887
# 0.414062  0.421875  0.417969  0.9345794392523363
# 0.417969  0.421875  0.419922  0.46511627906976744
# 0.417969  0.419922  0.418945  0.2331002331002331
# 0.417969  0.418945  0.418457  0.11668611435239205
# 0.417969  0.418457  0.418213  0.05837711617046118
# 0.418212890625

# %%
#5.4
import math
import matplotlib.pyplot as pl
from tabulate import tabulate

fo=[]
xo=[]

Es=0.5*10**-1
vVo=6.4051

def f(x):
    
    y=-12 - 21*x + 18*x**2 - 2.75*x**3
    
    return y

def met_falsa_pos(Xl,Xu):
    
    tabla=[]
    Xro=[]
    
    Ea=[]
    Eapx=1
    
    Xr=0.0
    
    c1=0
    
    while Eapx>Es:
    
        Xr=Xu-(f(Xu)*(Xl-Xu)/(f(Xl)-f(Xu)))
        #Ett=abs((vVo-Xr)/vVo)*100
        #Et.append(Ett)
        Xro.append(Xr)
        
        if(c1>0):
            Eapx=abs((((Xro[c1]-Xro[c1-1])/Xro[c1])*100))
            Ea.append(Eapx)
            tabla.append([Xl,Xu,Xr,Ea[c1-1]])
        else:
            tabla.append([Xl,Xu,Xr,""])
            
            
            
        if(f(Xl)*f(Xr))<0:
            Xu=Xr
        
        else:
            if(f(Xl)*f(Xr))>0:
                Xl=Xr
            else:
                break
                
        c1+=1
    
    print(tabulate(tabla,headers=["Xl","Xu","Xr","Ea"]))
    return Xr
   

def graf():
    
    print("")
    print("Raiz menor:",-0.432)
    print("")

    x=-50
    n=0
    
    while n<1000:
        fo.append(f(x))
        xo.append(x)
        x+=0.1
        n+=1
    
    pl.ylabel('f(X)')
    pl.xlabel('X')
   
    pl.plot(xo,fo,color="green",linewidth=2.5, linestyle="-")
   
    pl.axis([-5,15,-50,50])
    pl.grid(True)
    pl.show()

graf()
met_falsa_pos(-1,0)
# Out:
# Raiz menor: -0.432
#
#   Xl         Xu         Xr  Ea
# ----  ---------  ---------  -------------------
#   -1   0         -0.287425
#   -1  -0.287425  -0.379449  24.251950236430492
#   -1  -0.379449  -0.405232  6.36257916392447
#   -1  -0.405232  -0.412173  1.6840378668563465
#   -1  -0.412173  -0.414022  0.4464165358928404
#   -1  -0.414022  -0.414512  0.1183810177981495
#   -1  -0.414512  -0.414642  0.03139516995007155
# -0.4146424217052663

# %%
#5.3
import math
import matplotlib.pyplot as pl
from tabulate import tabulate

fo=[]
xo=[]

def f(x):
    
    y=-25 + 82*x - 90*x**2 + 44*x**3 - 8*x**4 + 0.75*x**5
    
    return y

def encontrarRaiz(Xl,Xu,ban):
    
    Ea=[]
    tabla=[]
    Xro=[]
    Es=0
    
    Xr=0.0
    Et=1
    Eapx=1
    
    c1=0
    
    while Eapx>Es:
    
        if(ban==True):  
            Es=0.1
            
            Xr=((Xl+Xu)/2)
            Xro.append(Xr)
        
            if(c1>0):
                Eapx=(abs((((Xro[c1]-Xro[c1-1])/Xro[c1])*100)))
                Ea.append(Eapx)
                tabla.append([c1+1,Xl,Xu,Xr,Eapx])
            
            else:
                tabla.append([c1+1,Xl,Xu,Xr,""])
                
        else:
            Es=0.002
            Xr=Xu-(f(Xu)*(Xl-Xu)/(f(Xl)-f(Xu)))
            Xro.append(Xr)
            
            if(c1>0):
                Eapx=(abs((((Xro[c1]-Xro[c1-1])/Xro[c1])*100)))
                Ea.append(Eapx)
                tabla.append([c1+1,Xl,Xu,Xr,Eapx])
            
            else:
                tabla.append([c1+1,Xl,Xu,Xr,""])
        
        
        if(f(Xl)*f(Xr))<0:
            Xu=Xr
        
        else:
            if(f(Xl)*f(Xr))>0:
                Xl=Xr
            else:
                break
                
        c1+=1
        
    headers=["Iteracion","Xl","Xu","Xr","Ea"]
    print(tabulate(tabla,headers))
    
def graf():
    
    print("")
    print("Valor exacto: ",0.5794)
    print("")
    
    x=-30
    n=0
    
    while n<500:
        fo.append(f(x))
        xo.append(x)
        x+=0.1
        n+=1
    
    pl.ylabel('f(X)')
    pl.xlabel('X')
   
    pl.plot(xo,fo,color="green",linewidth=2.5, linestyle="-")
   
    pl.axis([-8,8,-100,100])
    pl.grid(True)
    pl.show()


graf()
#metodo de biseccion
encontrarRaiz(0.5,1,True)
print("")
#metodo de falsa posicion
encontrarRaiz(0.5,1,False)
# Out:
# Valor exacto:  0.5794
#
#   Iteracion        Xl        Xu        Xr  Ea
# -----------  --------  --------  --------  -------------------
#           1  0.5       1         0.75
#           2  0.5       0.75      0.625     20.0
#           3  0.5       0.625     0.5625    11.11111111111111
#           4  0.5625    0.625     0.59375   5.263157894736842
#           5  0.5625    0.59375   0.578125  2.7027027027027026
#           6  0.578125  0.59375   0.585938  1.3333333333333335
#           7  0.578125  0.585938  0.582031  0.6711409395973155
#           8  0.578125  0.582031  0.580078  0.33670033670033667
#           9  0.578125  0.580078  0.579102  0.16863406408094433
#          10  0.579102  0.580078  0.57959   0.08424599831508003
#
#   Iteracion    Xl        Xu        Xr  Ea
# -----------  ----  --------  --------  ---------------------
#           1   0.5  1         0.641256
#           2   0.5  0.641256  0.587574  9.136139200406046
#           3   0.5  0.587574  0.580297  1.2540903026771408
#           4   0.5  0.580297  0.579349  0.16355895214469812
#           5   0.5  0.579349  0.579226  0.021179831191633924
#           6   0.5  0.579226  0.57921   0.002740098169048543
#           7   0.5  0.57921   0.579208  0.0003544519377931699

# %%
#5.6
import math
import matplotlib.pyplot as pl
from tabulate import tabulate

fo=[]
xo=[]

def f(x):
    
    y=math.log(x**2)-0.7
    
    return y

def encontrarRaiz(Xl,Xu,ban):
    
    Ea=[]
    tabla=[]
    Xro=[]
    Es=0
    
    Xr=0.0
    Et=1
    Eapx=1
    
    c1=0
    
    while c1<3:
    
        if(ban==True):  
            Es=0.1
            
            Xr=((Xl+Xu)/2)
            Xro.append(Xr)
        
            if(c1>0):
                Eapx=(abs((((Xro[c1]-Xro[c1-1])/Xro[c1])*100)))
                Ea.append(Eapx)
                tabla.append([c1+1,Xl,Xu,Xr,Eapx])
            
            else:
                tabla.append([c1+1,Xl,Xu,Xr,""])
                
        else:
            Es=0.002
            Xr=Xu-(f(Xu)*(Xl-Xu)/(f(Xl)-f(Xu)))
            Xro.append(Xr)
            
            if(c1>0):
                Eapx=(abs((((Xro[c1]-Xro[c1-1])/Xro[c1])*100)))
                Ea.append(Eapx)
                tabla.append([c1+1,Xl,Xu,Xr,Eapx])
            
            else:
                tabla.append([c1+1,Xl,Xu,Xr,""])
        
        
        if(f(Xl)*f(Xr))<0:
            Xu=Xr
        
        else:
            if(f(Xl)*f(Xr))>0:
                Xl=Xr
            else:
                break
                
        c1+=1
        
    headers=["Iteracion","Xl","Xu","Xr","Ea"]
    print(tabulate(tabla,headers))
    
def graf():
    
    print("")
    print("Valor exacto: ",1.4190)
    print("")
    
    x=-30
    n=0
    
    while n<500:
        fo.append(f(x))
        xo.append(x)
        x+=0.1
        n+=1
    
    pl.ylabel('f(X)')
    pl.xlabel('X')
   
    pl.plot(xo,fo,color="green",linewidth=2.5, linestyle="-")
   
    pl.axis([-8,8,-100,100])
    pl.grid(True)
    pl.show()


graf()
#metodo de biseccion
encontrarRaiz(0.5,2,True)
print("")
#metodo de falsa posicion
encontrarRaiz(0.5,2,False)
# Out:
# Valor exacto:  1.419
#
#   Iteracion    Xl     Xu      Xr  Ea
# -----------  ----  -----  ------  ------------------
#           1  0.5   2      1.25
#           2  1.25  2      1.625   23.076923076923077
#           3  1.25  1.625  1.4375  13.043478260869565
#
#   Iteracion    Xl       Xu       Xr  Ea
# -----------  ----  -------  -------  -----------------
#           1   0.5  2        1.62871
#           2   0.5  1.62871  1.49701  8.797053309705777
#           3   0.5  1.49701  1.4484   3.356518090871288

# %%
#5.7
import math
import matplotlib.pyplot as pl
from tabulate import tabulate

fo=[]
xo=[]

vV=2.6666

def f(x):
    
    y=(0.8-0.3*x)/x
    
    return y

def met_falsa_posicion(Xl,Xu):
    
    Ea=[]
    Et=[]
    tabla=[]
    Xro=[]
    
    Xr=0.0
    
    c1=0
    
    while c1<3:
    
            
        Xr=((Xl+Xu)/2)
        Xro.append(Xr)
        Et.append(abs(vV-Xr))
        
        if(c1>0):
            Eapx=(abs((((Xro[c1]-Xro[c1-1])/Xro[c1])*100)))
            Ea.append(Eapx)
            tabla.append([c1+1,Xl,Xu,Xr,Eapx,Et[c1]])
            
        else:
            tabla.append([c1+1,Xl,Xu,Xr,"",Et[c1]])
        
        if(f(Xl)*f(Xr))<0:
            Xu=Xr
        
        else:
            if(f(Xl)*f(Xr))>0:
                Xl=Xr
            else:
                break
                
        c1+=1
        
    headers=["Iteracion","Xl","Xu","Xr","Ea","Ever"]
    print(tabulate(tabla,headers))
    
def graf():
    
    print("")
    print("Valor exacto: ",2.6666)
    print("")
    
    x=-30
    n=0
    
    while n<500:
        fo.append(f(x))
        xo.append(x)
        x+=0.1
        n+=1
    
    pl.ylabel('f(X)')
    pl.xlabel('X')
   
    pl.plot(xo,fo,color="green",linewidth=2.5, linestyle="-")
   
    pl.axis([-8,8,-100,150])
    pl.grid(True)
    pl.show()


graf()
print("")
#metodo de falsa posicion
met_falsa_posicion(1,3)
# Out:
# Valor exacto:  2.6666
#
#
#   Iteracion    Xl    Xu    Xr  Ea                   Ever
# -----------  ----  ----  ----  -----------------  ------
#           1   1       3  2                        0.6666
#           2   2       3  2.5   20.0               0.1666
#           3   2.5     3  2.75  9.090909090909092  0.0834
