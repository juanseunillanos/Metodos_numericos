# %%
import math
import matplotlib.pyplot as plt
g=9.8
m=68.1
c=12.5
t=0
t1=2
v=0
ar= []
ar1=[]
ar2= []
ar22=[]

for i in range (120):
   if i==0:
    vi=0
    t=0
    print("%s %f" %(t, vi))
    ar1.append(t) 
    ar.append(vi)
   vi=(v+(g-(c/m*v))*(t1-t))
   print ("arreglo1 %s" % vi)
   ar1.append(t) 
   ar.append(vi)
   v=vi
   t=t1
   t1=t1+2
    
def vt(g, m,c,i):
 vta=(((g*m)/c)*(1-math.exp(-(c/m)*i))) 
 ar2.append(vta)
 ar22.append(i)
 print ("arreglo2 %s" % vta)  
    
for i in range(0,120):
 vt(g,m,c,i)


plt.plot(ar1, ar,'ro')
plt.plot(ar22, ar2)
plt.grid(True)
plt.axis([0, 80, 0, 100])
plt.show()
# Out:
# 0 0.000000
# arreglo1 19.6
# arreglo1 32.00469897209986
# arreglo1 39.85554369599859
# arreglo1 44.82428683256299
# arreglo1 47.968968612092
# arreglo1 49.959215083423864
# arreglo1 51.21882775470732
# arreglo1 52.01602755107027
# arreglo1 52.52056956609587
# arreglo1 52.83989057707389
# arreglo1 53.04198654731108
# arreglo1 53.169891632732856
# arreglo1 53.250841840980705
# arreglo1 53.30207464531965
# arreglo1 53.33449951855032
# arreglo1 53.35502098751129
# arreglo1 53.36800887755854
# arreglo1 53.37622881971767
# arreglo1 53.381431161965224
# arreglo1 53.384723686941285
# arreglo1 53.38680750230792
# arreglo1 53.388126334059784
# arreglo1 53.38896101318615
# arreglo1 53.38948927559946
# arreglo1 53.38982360907983
# arreglo1 53.390035206333934
# arreglo1 53.39016912471355
# arreglo1 53.39025388069243
# arreglo1 53.39030752214161
# arreglo1 53.39034147142883
# arreglo1 53.39036295768844
# arreglo1 53.39037655618755
# arreglo1 53.39038516257978
# arreglo1 53.390390609503505
# ...
